# %%
import pandas as pd
from pathlib import Path
import os

pd.set_option('display.max_columns', None)

# %%
gold_dir = Path("./data/gold/br101_rgi_weekly_panel")

# List dirs under gold_dir
os.listdir(gold_dir)
# Out:
# ['br101_rgi_weekly_panel']

# %%
canonical_accidents_by_rgi_section = pd.read_parquet(gold_dir / "canonical_accidents_by_rgi_section")
